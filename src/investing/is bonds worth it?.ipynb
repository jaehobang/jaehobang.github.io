# %%
import pandas as pd
import matplotlib.pyplot as plt

plt.figure()

# Read the CSV file into a Pandas DataFrame
data = pd.read_csv('../../data/investing/combined_graph.csv')

# Extract the columns we want to plot
years = data['Year']
returns = data['S&P 500 Avg. Return']
funds_rate = data['Federal Funds Rate']
inflation_rate = data['Avg. Inflation Rate']

# Plot the data as line charts
fig, ax = plt.subplots()
ax.plot(years, returns, label='S&P 500 Avg. Return')
ax.plot(years, funds_rate, label='Federal Funds Rate')
ax.plot(years, inflation_rate, label='Avg. Inflation Rate')

# Add a legend and title
ax.legend()
ax.set_title('S&P 500 Returns, Fed Funds Rate, and Inflation Rate (1973-2020)')

# Show the plot
plt.show()

# %%
import pandas as pd

# Read the CSV file into a Pandas DataFrame
data = pd.read_csv('../../data/investing/combined_graph.csv')

# Filter the DataFrame to only include rows between 1973 and 1983
subset = data[(data['Year'] >= 1973) & (data['Year'] <= 1983)]

# Compute the average of the 'Avg. Inflation Rate' column for the subset
average_inflation_rate = subset['Avg. Inflation Rate'].mean()

# Print the result
print('The average inflation rate from 1973 to 1983 was:', average_inflation_rate)
# Out:
# The average inflation rate from 1973 to 1983 was: 8.121818181818181

# %%
import pandas as pd

# Read the CSV file into a Pandas DataFrame
data = pd.read_csv('../../data/investing/combined_graph.csv')

# Compute the correlation coefficient between 'S&P 500 Avg. Return' and 'Federal Funds Rate'
correlation = data['S&P 500 Avg. Return'].corr(data['Federal Funds Rate'])

# Print the result
print('The correlation coefficient between S&P 500 average return and Federal Funds Rate is:', correlation)
# Out:
# The correlation coefficient between S&P 500 average return and Federal Funds Rate is: 0.04449564997852324

# %%
import pandas as pd

# Read the CSV file into a Pandas DataFrame
data = pd.read_csv('../../data/investing/combined_graph.csv')

# Compute the correlation coefficient between 'Federal Funds Rate' and 'Avg. Inflation Rate'
correlation = data['Federal Funds Rate'].corr(data['Avg. Inflation Rate'])

# Print the result
print('The correlation coefficient between Federal Funds Rate and Avg. Inflation Rate is:', correlation)
# Out:
# The correlation coefficient between Federal Funds Rate and Avg. Inflation Rate is: 0.7129696154273816

# %%
import pandas as pd

# Read the CSV file into a Pandas DataFrame
data = pd.read_csv('../../data/investing/combined_graph.csv')

# Filter the DataFrame to only include rows between 2010 and 2020
subset = data[(data['Year'] >= 2010) & (data['Year'] <= 2020)]

# Compute the average of the 'S&P 500 Avg. Return' column for the subset
average_return = subset['S&P 500 Avg. Return'].mean()

# Print the result
print('The average S&P 500 return from 2010 to 2020 was:', average_return)
# Out:
# The average S&P 500 return from 2010 to 2020 was: 14.107272727272727
